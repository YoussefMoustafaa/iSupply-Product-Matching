# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import re

# %%
xls = pd.ExcelFile("Product Matching Dataset.xlsx")

# %%
master_df = pd.read_excel(xls, "Master File")
dataset_df = pd.read_excel(xls, "Dataset")

# %%
dataset_df.head()
# Out:
#     sku marketplace_product_name_ar       seller_item_name  price
# 0  1322    استوهالت 40 مجم 14 كبسول  ESTOHALT 40 MG 14 CAP   56.5
# 1  1322    استوهالت 40 مجم 14 كبسول   استوهالت 40 مجم 14 ك   56.5
# 2  1322    استوهالت 40 مجم 14 كبسول   استوهالت 40 مجم 14 ك   56.5
# 3  1322    استوهالت 40 مجم 14 كبسول   استوهالت 40 مجم 14 ك   56.5
# 4  1322    استوهالت 40 مجم 14 كبسول   استوهالت 40 مجم 14 ك   56.5

# %%
master_df.head()
# Out:
#     sku                    product_name                product_name_ar  price
# 0   279          ANAFRONIL 75 MG 20 TAB  انافرونيل 75 مجم اس ار 20 قرص   75.0
# 1  2282         LOPRECOUGH SYRUP 100 ML           لوبريكاف شراب 100 مل   28.5
# 2  4331               TOMEX PLUS 50 TAB               تومكس بلس 50 قرص   60.0
# 3  1022     TAROLIMUS 0.03% OINT. 15 GM     تاروليمس 0.03 % مرهم 15 جم  129.0
# 4   116  GLIPTUS PLUS 50/1000 MG 30 TAB  جليبتس بلس 50/1000 مجم 30 قرص  192.0

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83562 entries, 0 to 83561
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   sku                          83562 non-null  int64
#  1   marketplace_product_name_ar  83562 non-null  object
#  2   seller_item_name             83562 non-null  object
#  3   price                        83562 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.6+ MB

# %% [markdown]
# ## 1. Data Preprocessing

# %% [markdown]
# ### a. Cleaning

# %%
def normalize_english(text):
    text = str(text).lower()
    # remove numbers (for master file only)
    text = re.sub(r'\d+', ' ', text)
    text = re.sub(r'[^a-z0-9\s]', ' ', text) # remove non-alphanumeric characters
    # text = re.sub(r'[^\w\s]', '', text) # remove punctuation
    text = re.sub(r'\s+', ' ', text) # remove multiple spaces
    text = text.strip()
    return text


def normalize_arabic(text):
    text = str(text).lower()
    text = re.sub(r"[\u064B-\u065F]", "", text)  # Remove Arabic diacritics (tashkeel)
    # text = re.sub(r'[^\u0621-\u064A\s]', '', text) # remove non-arabic characters
    text = re.sub(r'[^\u0621-\u064A0-9\s]', ' ', text) # remove non-arabic characters except for numbers
    text = re.sub(r'\s+', ' ', text) # remove multiple spaces

    text = re.sub( r'قرص|\bق\b|\bك\b|اقراص|كبسوله', 'كبسول', text)
    text = re.sub(r'([\u0600-\u06FF])\1+', r'\1', text) # remove arabic repetition
    text = re.sub(r'[إأآ]', 'ا', text)
    text = re.sub(r'ى', 'ي', text)
    text = re.sub(r'ة', 'ه ', text)
    text = re.sub(r'ؤ', 'و', text)
    text = re.sub(r'ئ', 'ي', text)

    # Separate numbers that stick to Arabic/English words
    text = re.sub(r"(\d+)([a-zA-Z\u0600-\u06FF]+)", r"\1 \2", text)  # Number followed by Arabic/English
    text = re.sub(r"([a-zA-Z\u0600-\u06FF]+)(\d+)", r"\1 \2", text)  # Arabic/English followed by number

    # Remove standalone Arabic/English characters (but not numbers)
    text = re.sub(r"\b[^\W\d]\b", "", text)
    
    text = re.sub(r'\b(?:سعر جديد|سعر|قديم|جديد|س جديد|س جدي|س ج|ركز)\b', '', text)# Remove specific unwanted phrases
    text = re.sub( r'مرهم|اكريم', 'كريم', text)
    text = re.sub(r'مليجرام|\bم\b|مجم', 'مجم', text)
    text = re.sub(r'جرام|جم', 'جم', text)
    text = re.sub( r'شرائط|شريطين', 'شريط', text)
    text = re.sub( r'امبولات|امبوله|حقن', 'امبول', text)
    text = re.sub( r'لبوس|لبوس اطفال', 'اقماع', text)
    text = re.sub(r"\s+", " ", text).strip() # remove multiple spaces
    return text

# %%
normalize_arabic("مرهم لعلاج2الجروح 10/200 جم")
# Out:
# 'كريم لعلاج 2 الجروح 10 200 جم'

# %%
normalize_arabic("بيوفيت امبول جديددددد")
# Out:
# 'بيوفيت امبول'

# %%
dataset_df['seller_item_name_clean'] = dataset_df['seller_item_name'].apply(normalize_arabic)

# %%
dataset_df.sample(10)
# Out:
#         sku        marketplace_product_name_ar            seller_item_name  \
# 37533   666              ال-كارنيتين 20 كبسولة            ال كارنتين كبسول
# 55063   293              كارنيفيتا فورت 30 قرص    كارنيفيتا فورت 3شريط س/ج
# 5501   2132          كولوماك محلول موضعى 10 مل       كوللوماك محلول س جديد
# 69413   692           دولفين 12.5 مجم 10 أقماع    دولفن 12.5 لبوس شريطييين
# 61617   357            ديامونركتا 5 مجم 30 قرص     ديمنريكتا 5 محم 30اقراص
# 38004   977             الكابريس 10 مجم 30 قرص        الكابريس 10مجم 3شريط
# 18810   747     انتيكوكس 15مجم/3مل 6 امبول عضل  انتى كوكس 6امبوله /سعرجديد
# 4540   1323              موبيتيل 15 مجم 10 قرص         موبيتيل 15مجم 10قرص
# 16047   237  تلفاست 30مجم/5مل شراب معلق 100 مل             تلفاست شراب/س ج
# 62819   479      فيبراميسين 100 مجم 10 كبسولات         فيبراميسين 10 كبسول
#
#        price     seller_item_name_clean seller_item_name_clean_spell
# 37533   72.0           ال كارنتين كبسول                ال كريم كبسول
# 55063  177.0      كارنيفيتا فورت 3 شريط        كارنيفيتا فورت 3 شريط
# 5501    18.0              كولوماك محلول             كولوماك محلول جي
# 69413   36.0      دولفن 12 5 اقماع شريط           دي 12 5 اقماع شريط
# 61617  187.5   ديمنريكتا 5 محم 30 كبسول            دي 5 محم 30 كبسول
# 38004   78.0     الكابريس 10 مجم 3 شريط       الكابريس 10 مجم 3 شريط
# 18810   78.0  انتي كوكس 6 امبول سعرجديد           ان كريم 6 امبول سي
# 4540    23.5    موبيتيل 15 مجم 10 كبسول      موبيتيل 15 مجم 10 كبسول
# 16047   50.0                تلفاست شراب                  تلفاست شراب
# 62819   42.5        فيبراميسين 10 كبسول          فيبراميسين 10 كبسول

# %%
def clean_master_file(text):
    text = str(text).lower()
    text = re.sub(r"[\u064B-\u065F]", "", text)  # Remove Arabic diacritics (tashkeel)

    text = re.sub(r'\d+', ' ', text) # remove numbers
    
    # text = re.sub(r'[^\u0621-\u064A\s]', '', text) # remove non-arabic characters
    text = re.sub(r'[^\u0621-\u064A0-9\s]', ' ', text) # remove non-arabic characters except for numbers
    text = re.sub(r'\s+', ' ', text) # remove multiple spaces

    text = re.sub( r'قرص|\bق\b|\bك\b|اقراص|كبسوله', 'كبسول', text)
    text = re.sub(r'([\u0600-\u06FF])\1+', r'\1', text) # remove arabic repetition
    text = re.sub(r'[إأآ]', 'ا', text)
    text = re.sub(r'ى', 'ي', text)
    text = re.sub(r'ة', 'ه ', text)
    text = re.sub(r'ؤ', 'و', text)
    text = re.sub(r'ئ', 'ي', text)

    # Separate numbers that stick to Arabic/English words
    text = re.sub(r"(\d+)([a-zA-Z\u0600-\u06FF]+)", r"\1 \2", text)  # Number followed by Arabic/English
    text = re.sub(r"([a-zA-Z\u0600-\u06FF]+)(\d+)", r"\1 \2", text)  # Arabic/English followed by number

    # Remove standalone Arabic/English characters (but not numbers)
    text = re.sub(r"\b[^\W\d]\b", "", text)
    
    text = re.sub(r'\b(?:سعر جديد|سعر|جديد|قديم|س جديد|س جدي|س ج|ركز)\b', '', text)# Remove specific unwanted phrases
    text = re.sub( r'مرهم|اكريم', 'كريم', text)
    text = re.sub( r'\bنقط\b', 'قطرة', text)
    text = re.sub(r'مليجرام|\bم\b|مجم', 'مجم', text)
    text = re.sub(r'جرام|جم', 'جم', text)
    text = re.sub( r'شرائط|شريطين', 'شريط', text)
    text = re.sub( r'امبولات|امبوله|حقن', 'امبول', text)
    text = re.sub( r'لبوس|لبوس اطفال', 'اقماع', text)
    text = re.sub(r"\s+", " ", text).strip() # remove multiple spaces
    return text

# %%
master_df['product_name_ar_clean'] = master_df['product_name_ar'].apply(clean_master_file)

# %%
master_df.sample(10)
# Out:
#       sku                                   product_name  \
# 277  1394                       ISOPTIN SR 240 MG 30 TAB
# 987   438                       BETADERM 0.1%CREAM 15 GM
# 58    121                             COLOVERIN-D 30 TAB
# 962  3883  SWABIVENT NEBULIZER SOLUTION AMP. 20 * 2.5 ML
# 187    60                       RIVAROSPIRE 10 MG 20 TAB
# 899  1789                    CIDOPHAGE 500 MG 50 STRIPES
# 393  2064                            ATACAND 4 MG 14 TAB
# 370  1863                            STROKA 75 MG 30 TAB
# 309  1517                       GLYCODAL 30 CHEWABLE TAB
# 774   303          BETADINE ANTISEPTIC 10%SOLUTION 60 ML
#
#                                product_name_ar   price  \
# 277              ايسوبتن ريتارد 240 مجم 30 قرص   97.50
# 987                   بيتاديرم 0.1% كريم 15 جم   18.00
# 58                         كولوفيرين دى 30 قرص  105.00
# 962  سوابيفنت 500 ميكرو محلول استنشاق 20 امبول  176.00
# 187                   ريفاروسبير 10 مجم 20 قرص  254.00
# 899                    سيدوفاج 500 مجم 50 شريط  550.00
# 393                       اتاكاند 4 مجم 14 قرص   39.75
# 370                       ستروكا 75 مجم 30 قرص  145.00
# 309                        جليكودال 30 قرص مضغ   57.00
# 774         بيتادين 10% محلول مطهر 60 مل موندى   55.00
#
#                   product_name_ar_clean
# 277            ايسوبتن ريتارد مجم كبسول
# 987                    بيتاديرم كريم جم
# 58                   كولوفيرين دي كبسول
# 962  سوابيفنت ميكرو محلول استنشاق امبول
# 187                ريفاروسبير مجم كبسول
# 899                    سيدوفاج مجم شريط
# 393                   اتاكاند مجم كبسول
# 370                    ستروكا مجم كبسول
# 309                  جليكودال كبسول مضغ
# 774         بيتادين محلول مطهر مل موندي

# %%
master_df['product_name_ar_clean'] = master_df['product_name_ar'].apply(normalize_arabic)
products_list = master_df['product_name_ar_clean'].str.split().str[0].apply(lambda x: x if len(x) >= 3 else None).dropna().tolist()
products_list = list(set(products_list))
print(len(products_list))
products_list
# Out:
# 1000
# 0      [انافرونيل, 75, مجم, اس, ار, 20, كبسول]
# 1                    [لوبريكاف, شراب, 100, مل]
# 2                      [تومكس, بلس, 50, كبسول]
# 3              [تاروليمس, 0, 03, كريم, 15, جم]
# 4      [جليبتس, بلس, 50, 1000, مجم, 30, كبسول]
#                         ...
# 995          [سولفاكس, بلس, مساج, جيل, 60, جم]
# 996              [مودابكس, 50, مجم, 30, كبسول]
# 997              [كابرون, 500, مجم, 20, كبسول]
# 998             [جارديانس, 10, مجم, 30, كبسول]
# 999              [ايموكس, 500, مجم, 16, كبسول]
# Name: product_name_ar_clean, Length: 1000, dtype: object

# %%
# Create a list of all unique product names in the master file
master_product_names = master_df['product_name_ar_clean'].unique()
len(master_product_names)
# split the list into unique words
master_product_words = set(" ".join(master_product_names).split())
len(master_product_words)
master_product_words
# Out:
# {'مساج',
#  'بانتازول',
#  'اميلو',
#  'اميجران',
#  'ديبافالي',
#  'جافيسكون',
#  'ريباريل',
#  'انتيكوكس',
#  'دولفين',
#  'بنادول',
#  'جينت',
#  'ريتارد',
#  'ليفوهيستام',
#  'ستروبانتين',
#  '56',
#  'روسيتور',
#  'اتاكاند',
#  'غسول',
#  'توبراديكس',
#  'ليبراكس',
#  '550',
#  'اقلام',
#  'لعين',
#  'ار',
#  'بلس',
#  'فتله',
#  'توجيو',
#  'بريدوكاين',
#  'تيكانيز',
#  'بريستافلام',
#  'كولونا',
#  'لي',
#  '35',
#  'بالحديد',
#  'فيوسي',
#  '40',
#  'مفيس',
#  'بكتيكلور',
#  'اسيكلوفير',
#  'بريجناكير',
#  'ادفانسد',
#  'كو',
#  'فيلدافورمين',
#  '81',
#  'ريفو',
#  'ملطف',
#  'اوفيوسيديك',
#  '32',
#  '25',
#  'اند',
#  'استيل',
#  'دايجيست',
#  'رومانتيجرا',
#  'يوريبان',
#  '2800',
#  'نستوجين',
#  'سولوستار',
#  'تادانيرفي',
#  'ايفيبرونت',
#  'تادالونج',
#  'استرازنيكا',
#  'ديابيتونورم',
#  'ريفارسبير',
#  'نازاكورت',
#  'وجه',
#  'سيبروفلوكساسين',
#  'مطهر',
#  'ليفانيك',
#  'جوينت',
#  'بانادول',
#  'بلادوجرا',
#  'فوليك',
#  'كوليروز',
#  'امريزول',
#  'نافوبروكسين',
#  'افازير',
#  'انتريستو',
#  'معباه',
#  'نيرفيزام',
#  'انسيلاكوكس',
#  'جوينتا',
#  'ملح',
#  'كارنيتين',
#  'ميلانوفري',
#  'موديوريتك',
#  '6',
#  'انترافارما',
#  'اوجم',
#  'كريستوليب',
#  'بروفينيد',
#  'الفيولين',
#  'ساليبت',
#  'لمضغ',
#  'دوزين',
#  'انافرونيل',
#  'ابل',
#  'سيكودال',
#  '220',
#  'نورفاسك',
#  'فلوكسامو',
#  'كاردورا',
#  'بروتوفيكس',
#  'انتينال',
#  'زانوجلايد',
#  'دايجست',
#  'او',
#  '14',
#  'نيتروماك',
#  'بروليا',
#  'موبيتيل',
#  'تراياكتين',
#  'نيرهاسيلدا',
#  'ديباكين',
#  '075',
#  'سيبيوم',
#  'فورت',
#  'جنكوبيلوبا',
#  'رواتينكس',
#  'سكروفير',
#  'اوليف',
#  'ادويفلام',
#  'نوفورابيد',
#  'يوريكير',
#  'فيجاموكس',
#  'فاستر',
#  'سيلسيبت',
#  'بالفم',
#  'اتورستات',
#  'ميرونيم',
#  'كونتافيفر',
#  '05',
#  'نيوتراسينس',
#  'لاستنشاق',
#  'بران',
#  'مضاعف',
#  'انتينسيف',
#  'جليبتس',
#  'ارثروفاست',
#  'اولابكس',
#  'هيد',
#  'كيتولاك',
#  '5000',
#  'مالوكس',
#  'كوتارج',
#  'جويبوكس',
#  'فيروجلوبين',
#  'تومكس',
#  '500',
#  '0',
#  'انترافارم',
#  'ستيرونات',
#  'بروباميثون',
#  'بليجيكا',
#  'كابس',
#  'كيتوجيسيك',
#  'نيوكاربون',
#  'اتور',
#  'فيمتونكس',
#  'كالم',
#  'ملي',
#  'امبيزيم',
#  'شريط',
#  'بيتولفكس',
#  '457',
#  'برونشيكم',
#  'جليميبرايد',
#  'سيتيال',
#  'فلاتيديل',
#  'زيروفازيت',
#  'ريمواكس',
#  'جاراميسين',
#  'ازماكاست',
#  'عسل',
#  'دولسيل',
#  'مارنيز',
#  'كولوفاتيل',
#  'بلينديل',
#  'بون',
#  'ابتاميل',
#  'ميزوسيبت',
#  'مايوديورا',
#  '60',
#  'ديكساترول',
#  'سيدوفاج',
#  'برو',
#  'بيكتول',
#  'الير',
#  'اليكسر',
#  '18',
#  'الزايم',
#  'ايه',
#  'ثلاجه',
#  'سنجيولير',
#  'برجاتون',
#  'مكجم',
#  'قمع',
#  'برونكوبرو',
#  'الفم',
#  'جاروبرايد',
#  'سليم',
#  'ياسمين',
#  'ماكسيكال',
#  'نت',
#  'كولوماك',
#  'كومب',
#  'بيتاديرم',
#  'فاست',
#  'برونتو',
#  'سيفوتاكس',
#  '55',
#  'انتوكس',
#  'بروكاسوفت',
#  '1680',
#  'فيبراميسين',
#  'هيرو',
#  'كريستور',
#  'ماغنسيوم',
#  'لاكريتيرز',
#  'جي',
#  'فيتايامي',
#  'فاردينوريكت',
#  'لذوبان',
#  'نيفيلوب',
#  'فيوسيدين',
#  'فلوموسيل',
#  'ايزي',
#  'انتوبرال',
#  'مادوفيت',
#  'ديوريسيف',
#  'روتاسي',
#  'الكوفان',
#  'اترابكس',
#  'باور',
#  'بريزولين',
#  'رواكول',
#  'دانست',
#  'بروستانورم',
#  'اوسوفورتين',
#  'ميوفين',
#  'استشاق',
#  'كوادريديرم',
#  'كلوريد',
#  'مودابكس',
#  'فيموجيسال',
#  'لوسيون',
#  'سليبريكس',
#  'سي',
#  'كونجي',
#  'بنتامكس',
#  'موزابرايد',
#  'فروت',
#  '1',
#  'اوركس',
#  'فاسكولار',
#  'كيناكومب',
#  'اسبريكارلو',
#  'عدسات',
#  'الفا',
#  'هيلسيك',
#  'موكسيفلوكس',
#  'تروليسيتي',
#  'نيوروباتكس',
#  'ثيوتاسيد',
#  'جينيرا',
#  'اوكساليبتال',
#  'سيريلاك',
#  'اورجينال',
#  'اوكاربون',
#  'اكتينون',
#  'اتش',
#  'بروزاك',
#  'اكساميد',
#  'وينديبين',
#  'بريليك',
#  'نازونكس',
#  'ايموكسكلاف',
#  'كوديلاترول',
#  'كوباد',
#  'بخاخ',
#  'نكتاليا',
#  'دوليبران',
#  'ريج',
#  'محلول',
#  'اليمبوسيس',
#  'قمح',
#  'قطعه',
#  'تريتاس',
#  'موندي',
#  'زولادكس',
#  'مومينتا',
#  'سبازمو',
#  'انتروجرمينا',
#  'فلوكا',
#  'سيفترياكسون',
#  'بيتادين',
#  'سريع',
#  'نقط',
#  'فوم',
#  'اوبلكس',
#  'يونيكتام',
#  'باوريكتا',
#  'دوستينكس',
#  'فياجرا',
#  'كبسوله',
#  '3',
#  'افيروزوليد',
#  'فوناسبير',
#  'سيلدافا',
#  'برين',
#  'سيبروديازول',
#  'نيوتراديفينس',
#  'اولفنت',
#  'اوميجا',
#  'اوكاس',
#  'لوك',
#  'يوريفين',
#  'فنجيكان',
#  'برايم',
#  'فارماكتيف',
#  'سولفاكس',
#  'بيوتين',
#  'دانتريلاكس',
#  'جاتيستار',
#  'اطفال',
#  'ديامونركتا',
#  'لوفير',
#  'زوركال',
#  'لاميكتال',
#  'ديجليفلوز',
#  '42',
#  'سومازينا',
#  'سيلجون',
#  'بلوكاتنس',
#  'بي',
#  'سبازمورست',
#  'فوليكاب',
#  'تريو',
#  'تيكافير',
#  'سينوبريل',
#  'اورسوفالك',
#  'فلاكورت',
#  'جليكودال',
#  'ادكو',
#  'سايميدل',
#  'اكتوفنت',
#  'ايفيروسبان',
#  'اوركاديكسولين',
#  'فاروفيجا',
#  'برافاماكس',
#  'جاهز',
#  'اميون',
#  'لبالغين',
#  'فليكتور',
#  'اير',
#  '03',
#  'ايبانتين',
#  'ديبرام',
#  'مركب',
#  'فيت',
#  'تريفاستال',
#  'ويلمان',
#  'ميكرو',
#  'دياسيرين',
#  'زيثرون',
#  'لاميفين',
#  'ديفيدو',
#  'جلوكوفاج',
#  'طرق',
#  'ريسباتيو',
#  'ايريوس',
#  'هيرتونيك',
#  'تافاسين',
#  'شاي',
#  '100',
#  'اميجراويست',
#  'باي',
#  'مل',
#  'ديسبركام',
#  'تريسيبا',
#  'معد',
#  'مع',
#  'بيونال',
#  'ايروكسول',
#  'هيليكيور',
#  'لشعر',
#  'كيتوفان',
#  'الدوميت',
#  'ديكساميثازون',
#  '45',
#  'كوردارون',
#  'اليفو',
#  'فينادون',
#  'فورسيجا',
#  'كبسول',
#  'بلافيكس',
#  'تافانيك',
#  '240',
#  'تينشن',
#  'بدياشور',
#  'سكارو',
#  'تامسولين',
#  'جينوكونازول',
#  '850',
#  'فلتر',
#  '15',
#  '21',
#  'فابوزول',
#  'كروميوم',
#  'جينوفيل',
#  'لاذن',
#  'ديكسافلوكس',
#  'جاناتون',
#  'صوديوم',
#  'برتقال',
#  'سيبراليكس',
#  'الوكيتا',
#  'فايركتا',
#  'امبول',
#  'اماريل',
#  'ابيكسيدون',
#  'ليمتلس',
#  'هيبارين',
#  'المهن',
#  'رغوي',
#  'بلوم',
#  'بودر',
#  'فافرين',
#  '4',
#  'تارجوفلوكسين',
#  'اوريجينال',
#  'فلو',
#  'كارنيفيتا',
#  'اسيد',
#  'ادابالين',
#  'عن',
#  'افيل',
#  'بروستريد',
#  'هاي',
#  'ايبيكو',
#  'مويست',
#  'شوجارلو',
#  'سيلفر',
#  'اقماع',
#  'داي',
#  'تارج',
#  'كيتوستريل',
#  'ميبو',
#  'مذيب',
#  'بيتميجا',
#  'زنك',
#  'تيراتام',
#  'تورسيريتك',
#  'خرطوش',
#  'ميتاكارديا',
#  'دياكيوريماب',
#  'تجريتول',
#  'بامبينو',
#  'ايزاكارد',
#  'هيموجيت',
#  'البافيت',
#  'كرونو',
#  'ايزوتريتينوين',
#  'توسيفان',
#  'جابيماش',
#  'موفينتور',
#  'كلاسيد',
#  'ابيكوبرد',
#  'فيلم',
#  'برناسورس',
#  'فاستافلام',
#  'اوميز',
#  'املوديبين',
#  'جلوكوز',
#  'لاسيكس',
#  'لوبريكاف',
#  'لانف',
#  'الجزال',
#  'ميجافين',
#  'فلوكس',
#  'فيوسيكورت',
#  'الفانوفا',
#  'قابل',
#  'زجاجه',
#  'اف',
#  'الكابرايد',
#  'ليمون',
#  'ديفلوكان',
#  'ديودارت',
#  '642',
#  'ريبلس',
#  'اريك',
#  'ماكسيلاز',
#  'سيستان',
#  'ريزوديج',
#  '800',
#  'دوسباتالين',
#  'سبانيلا',
#  'ديبو',
#  'كلوزابكس',
#  'بتك',
#  'زيستريل',
#  'فاكتو',
#  'لشرب',
#  'بترو',
#  'انتودين',
#  'فيسرالجين',
#  'شامبو',
#  'كارباميد',
#  'ميكستارد',
#  'توينزول',
#  'سيريتايد',
#  'كورتيبليكس',
#  'جالفس',
#  'القوه',
#  'الفافيم',
#  'فيافاج',
#  'فلوبادكس',
#  'شراب',
#  'اجركس',
#  'ريفاروسبير',
#  'معبا',
#  'سيتراك',
#  'كانزارتان',
#  'فرتيتونكس',
#  'كروميترون',
#  'عين',
#  'الترا',
#  'اس',
#  'جل',
#  'مج',
#  'سيمباتكس',
#  'جوسبرين',
#  'فلاجيل',
#  'مايجرين',
#  'لينكس',
#  'سيتابرونكس',
#  'ابيدون',
#  '200',
#  'بيوفيت',
#  'الفينترن',
#  'ميرالجو',
#  'سيالس',
#  'ديكلوفين',
#  'بخاخه',
#  'ارث',
#  'لانتوس',
#  'ديكسازون',
#  'ليليبيل',
#  'فورموهال',
#  'فورتيموكس',
#  'دولوكسبرين',
#  'ديكابرينو',
#  'لكبار',
#  'دوجماتيل',
#  'دافلون',
#  'محم',
#  'سلفستر',
#  'بيرفورما',
#  'مونوماك',
#  'ميجاموكس',
#  'فليكس',
#  'خرطوشه',
#  'بانتولوك',
#  'بيبيلاك',
#  'كويتابكس',
#  'دينستين',
#  'كونفنتين',
#  'اكس',
#  'زيثروسين',
#  'دوفاستون',
#  'سيرفيتام',
#  '300',
#  'فيلداجلوز',
#  'فيدروب',
#  'بيرفكت',
#  'ايملجيل',
#  'بيبي',
#  '8',
#  'مت',
#  'سالبوفنت',
#  'دوروفين',
#  'فيال',
#  'زيلون',
#  'بريستو',
#  'فورفلوزين',
#  'مزيل',
#  'سيفاكسون',
#  'كالسيوم',
#  'يوروسولفين',
#  'ديسكس',
#  'هيدروفيرين',
#  'ايزيس',
#  'برونتوجيست',
#  'تاروليمس',
#  'انف',
#  'ميت',
#  'ليدوكاين',
#  'فلورست',
#  'فليكسوفان',
#  'سرنجه',
#  'سريبروليسين',
#  'انكونت',
#  'هيستازين',
#  'احادي',
#  '900',
#  'دلتافيت',
#  'ماج',
#  '9',
#  'ايزوتونيك',
#  'اورليستات',
#  'بوليمير',
#  'ديفاكوت',
#  'فريش',
#  'لاحتقان',
#  'مافيلور',
#  'فيتامين',
#  'سيمبيكورت',
#  'ماكرو',
#  'اليكا',
#  'دوليه',
#  '7',
#  'براديبيكت',
#  'دنتينوكس',
#  'جراليبنتين',
#  'وحده',
#  'ثرومبكس',
#  'اميبرايد',
#  'كوبال',
#  'تريب',
#  'بيبانثين',
#  'لزجه',
#  'بليون',
#  'كتافلام',
#  'ترنتال',
#  'فلاكسوبرايد',
#  'اوبتامينس',
#  'ميرتيماش',
#  'سينجاردي',
#  'العضلي',
#  'زيثروماكس',
#  'كومبليت',
#  'تلفاست',
#  'جولد',
#  '22',
#  'كاندلكان',
#  'اكتومثرين',
#  'الذوبان',
#  'كونكور',
#  'كلاريتين',
#  'فوراديل',
#  'اديمكس',
#  'ديفلوستيرو',
#  'ماء',
#  'التسريب',
#  'بيسكالدين',
#  'ميثايلتكنو',
#  'اكسفورج',
#  'ازيلاست',
#  'اناليرج',
#  'ان',
#  'الجرعه',
#  'لاري',
#  'سنترم',
#  'تي',
#  'بالميكورت',
#  'جارد',
#  'توب',
#  'ديكلوبرو',
#  'فيتاسيد',
#  'يوريكونترول',
#  'اوجمنتين',
#  '215',
#  'تربوهيلر',
#  'هيربانا',
#  'فيرسيرك',
#  'اورلي',
#  'دايجينورم',
#  'ميوكوفيلين',
#  'ميراج',
#  'لوبريفيسك',
#  'كير',
#  'حبيبات',
#  'بالسكر',
#  'ايتوماش',
#  'بدون',
#  'كونترول',
#  'اوندالينز',
#  'رجكور',
#  'سالين',
#  'جابتن',
#  'امبوله',
#  'تراجينتا',
#  'زيرتيك',
#  'زيثروكان',
#  'ساكسندا',
#  'جانوميت',
#  'نيكسيكيور',
#  'فري',
#  'التراكاين',
#  'بيفاتراسين',
#  'بريدسول',
#  'تيرز',
#  'ريكوكسيبرايت',
#  'ستاركوبريكس',
#  'بيبزول',
#  'مونوريل',
#  'اسبرين',
#  '70',
#  '625',
#  'الكابريس',
#  'ايمباكوزا',
#  '80',
#  'اوكيوجارد',
#  '600',
#  'كال',
#  'كيبرا',
#  'مينوكسيلوك',
#  'فيمارا',
#  'دلتارينو',
#  'ميباكو',
#  'ساندوز',
#  'ليمتليس',
#  'اي',
#  'ديمرا',
#  'مهبلي',
#  'رينكس',
#  'اليكاسال',
#  'فاركو',
#  'بيرفيكتيل',
#  'ستاين',
#  'فبيوريك',
#  'مجم',
#  'ستروكا',
#  'اليكويس',
#  '20',
#  'معلق',
#  'اوكتاترون',
#  'سوماتروبين',
#  'نكسيام',
#  'كور',
#  'ابيمول',
#  'الفتح',
#  'انشور',
#  '160',
#  'سويت',
#  'توبمود',
#  'سبيكتون',
#  'بايولجام',
#  'فلوموكس',
#  'اندرال',
#  'استوهالت',
#  'تولانجو',
#  '30',
#  'سيديكو',
#  'اوروفكس',
#  'اسبوسيد',
#  'ديافلوزيمت',
#  'ايسوبتن',
#  'افيميو',
#  'جيل',
#  'سولوفريش',
#  'دورميفال',
#  'لجسم',
#  'تيبونينا',
#  'كولوفيرين',
#  'لاطفال',
#  'اكوا',
#  'ازجوفانس',
#  'ماكس',
#  'زوفيراكس',
#  'كلوباترا',
#  'نيورونتين',
#  'الزميندا',
#  'توسكان',
#  'ديورجوي',
#  'سيلينيوم',
#  'ديبروساليك',
#  '2000',
#  'لرجال',
#  'كابرون',
#  'ام',
#  'دالاسين',
#  'سيلوكينزوك',
#  'ميوكوستا',
#  'لسيدات',
#  'زنكترون',
#  'بيبون',
#  'اتوريزا',
#  'المتحدون',
#  'كلوبكس',
#  'كلافيموكس',
#  'توسيستوب',
#  'اوستيوكير',
#  'ايزابريل',
#  'تكلو',
#  'بيوتك',
#  'فواره',
#  'اريسبت',
#  'فنتال',
#  'اميولانت',
#  'سوبراكس',
#  'نورجيسيك',
#  'ريجين',
#  'بروكسيمول',
#  '64',
#  'بولي',
#  'اورجانو',
#  'دايت',
#  'كريم',
#  'اميونو',
#  'برس',
#  'ميلجا',
#  'لايت',
#  'فولتارين',
#  'سيريبروماب',
#  'فوميبريك',
#  'ديلاترول',
#  'تراي',
#  'ايبوتين',
#  'فاستاريل',
#  'لازيلاكتون',
#  'استحلاب',
#  'عضل',
#  'جليسرين',
#  'اوتريفين',
#  'سيتال',
#  'مضغ',
#  'رومارين',
#  '1100',
#  'كيريلا',
#  'اريميدكس',
#  'كت',
#  'سوفيناسين',
#  '90',
#  'مضمضه',
#  'ريجيم',
#  'لوتين',
#  'فانيليا',
#  'بيتاسيرك',
#  'لوسترال',
#  'تاتش',
#  '24',
#  'بيرفيكتوديل',
#  'تاريفيد',
#  'ابيكوتيل',
#  'فيتاستريس',
#  'بيبرا',
#  'تحت',
#  'فلاجيلات',
#  'بليتال',
#  'بينوكس',
#  'ستربتوكين',
#  'ستربسلز',
#  'سبراي',
#  'توبرين',
#  '75',
#  'زيرتك',
#  'داباجليف',
#  'قلم',
#  'بريج',
#  'كالدين',
#  'الوريدي',
#  '1200',
#  'يتامبن',
#  'نيوروتون',
#  'نيوروفيت',
#  'سيردالود',
#  'زوراكسون',
#  'سوابيفنت',
#  '180',
#  'زيجدو',
#  '16',
#  'ديكلاك',
#  'رويال',
#  'ريلاكسون',
#  'العامريه',
#  'ميكروسيرك',
#  '28',
#  'نوتوسيل',
#  'افيفافاسك',
#  'اكسارونت',
#  'سويتال',
#  'كيس',
#  'كتافاست',
#  'نورمو',
#  '150',
#  'ال',
#  '57',
#  'ديكساتوبرين',
#  '120',
#  'اومنيفورا',
#  'فاستل',
#  'سانسو',
#  'داونوبرازول',
#  'مان',
#  'ميوكوتك',
#  'افيكسور',
#  'فليكسونيز',
#  'بانثينول',
#  'لامبول',
#  'وريد',
#  'جانوفيا',
#  'بارامول',
#  'ستارفيل',
#  'سليبيز',
#  'فوربيودس',
#  'زون',
#  'دابوكستارد',
#  'دافاليندي',
#  '4000',
#  'كالسيترون',
#  'الجلد',
#  '2',
#  'فيل',
#  'كولد',
#  'بكتي',
#  'فوناسيدان',
#  'كيور',
#  'السان',
#  'افوصويا',
#  'اركوكسيا',
#  'البندازول',
#  'نانازوكسيد',
#  'جينوزول',
#  'متد',
#  'ريفارست',
#  'انجيكتمول',
#  'ليفسيت',
#  'اوزمبك',
#  'ميليتوفكس',
#  'المفعول',
#  'كروماكس',
#  'دياميكرون',
#  'اولفين',
#  'ديبوفيت',
#  'موضعي',
#  'نايت',
#  'بريمبران',
#  'راني',
#  '12',
#  'بروتكت',
#  'اماجلوست',
#  'روز',
#  'ليفابيون',
#  'غريب',
#  'دوفالاك',
#  'ماريفان',
#  'رجيماكس',
#  'ازماتك',
#  'فينتوكف',
#  'قطره',
#  'كبسولات',
#  '400',
#  'نعناع',
#  'ابيدرا',
#  'سيبتازول',
#  'بروكورلان',
#  'ليبيتور',
#  'جستيكول',
#  'ناتريليكس',
#  'داونستيرولين',
#  'جارديانس',
#  'ايميرست',
#  '000',
#  'شان',
#  'بلينك',
#  'اذن',
#  'سيبرا',
#  'فوار',
#  'ويست',
#  '50',
#  'جاست',
#  'ايموكس',
#  'ازموراب',
#  '48',
#  'زنكوديرم',
#  'دوكسيرازول',
#  'لبن',
#  '5',
#  'اومنيك',
#  'دي',
#  'اورسو',
#  '320',
#  'ديب',
#  'بريمونيدين',
#  'ايفرزين',
#  'برافوتين',
#  'كلير',
#  'نوستامين',
#  'ماش',
#  'جرعه',
#  'جاستروبيوتك',
#  'كونترولوك',
#  'ادفانس',
#  'بيكوزيم',
#  '1000',
#  'بالبرتقال',
#  'كليكسان',
#  'بالانف',
#  'لوشن',
#  ...}

# %%
product_names = master_df['product_name_ar_clean'].unique().tolist()
# Create a frequency dictionary (equal frequency for all names)
word_freq_dict = {name: 100 for name in products_list}
word_freq_dict
# Out:
# {'بانتازول': 100,
#  'اميلو': 100,
#  'اميجران': 100,
#  'ديبافالي': 100,
#  'جافيسكون': 100,
#  'ريباريل': 100,
#  'انتيكوكس': 100,
#  'دولفين': 100,
#  'بنادول': 100,
#  'ليفوهيستام': 100,
#  'ستروبانتين': 100,
#  'روسيتور': 100,
#  'اتاكاند': 100,
#  'توبراديكس': 100,
#  'ليبراكس': 100,
#  'توجيو': 100,
#  'بريدوكاين': 100,
#  'تيكانيز': 100,
#  'بريستافلام': 100,
#  'كولونا': 100,
#  'فيوسي': 100,
#  'بكتيكلور': 100,
#  'بريجناكير': 100,
#  'اسيكلوفير': 100,
#  'فيلدافورمين': 100,
#  'ريفو': 100,
#  'اوفيوسيديك': 100,
#  'استيل': 100,
#  'دايجيست': 100,
#  'رومانتيجرا': 100,
#  'يوريبان': 100,
#  'نستوجين': 100,
#  'تادانيرفي': 100,
#  'ايفيبرونت': 100,
#  'تادالونج': 100,
#  'ديابيتونورم': 100,
#  'ريفارسبير': 100,
#  'نازاكورت': 100,
#  'سيبروفلوكساسين': 100,
#  'ليفانيك': 100,
#  'جوينت': 100,
#  'بانادول': 100,
#  'بلادوجرا': 100,
#  'فوليك': 100,
#  'كوليروز': 100,
#  'امريزول': 100,
#  'نافوبروكسين': 100,
#  'افازير': 100,
#  'انتريستو': 100,
#  'نيرفيزام': 100,
#  'انسيلاكوكس': 100,
#  'جوينتا': 100,
#  'ميلانوفري': 100,
#  'موديوريتك': 100,
#  'اوجم': 100,
#  'كريستوليب': 100,
#  'الفيولين': 100,
#  'ساليبت': 100,
#  'دوزين': 100,
#  'انافرونيل': 100,
#  'ابل': 100,
#  'سيكودال': 100,
#  'نورفاسك': 100,
#  'فلوكسامو': 100,
#  'كاردورا': 100,
#  'بروتوفيكس': 100,
#  'انتينال': 100,
#  'زانوجلايد': 100,
#  'نيتروماك': 100,
#  'بروليا': 100,
#  'موبيتيل': 100,
#  'تراياكتين': 100,
#  'نيرهاسيلدا': 100,
#  'ديباكين': 100,
#  'جنكوبيلوبا': 100,
#  'رواتينكس': 100,
#  'سكروفير': 100,
#  'ادويفلام': 100,
#  'نوفورابيد': 100,
#  'يوريكير': 100,
#  'فيجاموكس': 100,
#  'فاستر': 100,
#  'سيلسيبت': 100,
#  'اتورستات': 100,
#  'ميرونيم': 100,
#  'اريميدكس': 100,
#  'كونتافيفر': 100,
#  'بران': 100,
#  'جليبتس': 100,
#  'ارثروفاست': 100,
#  'اولابكس': 100,
#  'كيتولاك': 100,
#  'مالوكس': 100,
#  'كوتارج': 100,
#  'جويبوكس': 100,
#  'فيروجلوبين': 100,
#  'تومكس': 100,
#  'بروباميثون': 100,
#  'ستيرونات': 100,
#  'بليجيكا': 100,
#  'اتور': 100,
#  'فيمتونكس': 100,
#  'امبيزيم': 100,
#  'بيتولفكس': 100,
#  'برونشيكم': 100,
#  'جليميبرايد': 100,
#  'سيتيال': 100,
#  'فلاتيديل': 100,
#  'زيروفازيت': 100,
#  'ريمواكس': 100,
#  'جاراميسين': 100,
#  'ازماكاست': 100,
#  'دولسيل': 100,
#  'مارنيز': 100,
#  'كولوفاتيل': 100,
#  'بلينديل': 100,
#  'بون': 100,
#  'ابتاميل': 100,
#  'ميزوسيبت': 100,
#  'مايوديورا': 100,
#  'ديكساترول': 100,
#  'سيدوفاج': 100,
#  'بيكتول': 100,
#  'الير': 100,
#  'سنجيولير': 100,
#  'برجاتون': 100,
#  'برونكوبرو': 100,
#  'جاروبرايد': 100,
#  'ياسمين': 100,
#  'ماكسيكال': 100,
#  'كولوماك': 100,
#  'بيتاديرم': 100,
#  'فاست': 100,
#  'برونتو': 100,
#  'سيفوتاكس': 100,
#  'انتوكس': 100,
#  'بروكاسوفت': 100,
#  'فيبراميسين': 100,
#  'هيرو': 100,
#  'كريستور': 100,
#  'ماغنسيوم': 100,
#  'لاكريتيرز': 100,
#  'فيتايامي': 100,
#  'فاردينوريكت': 100,
#  'نيفيلوب': 100,
#  'فيوسيدين': 100,
#  'فلوموسيل': 100,
#  'انتوبرال': 100,
#  'مادوفيت': 100,
#  'ديوريسيف': 100,
#  'روتاسي': 100,
#  'باور': 100,
#  'اترابكس': 100,
#  'بريزولين': 100,
#  'رواكول': 100,
#  'دانست': 100,
#  'بروستانورم': 100,
#  'ميوفين': 100,
#  'كوادريديرم': 100,
#  'مودابكس': 100,
#  'فيموجيسال': 100,
#  'سليبريكس': 100,
#  'كونجي': 100,
#  'بنتامكس': 100,
#  'موزابرايد': 100,
#  'فاسكولار': 100,
#  'اوركس': 100,
#  'كيناكومب': 100,
#  'اسبريكارلو': 100,
#  'هيلسيك': 100,
#  'موكسيفلوكس': 100,
#  'تروليسيتي': 100,
#  'نيوروباتكس': 100,
#  'ثيوتاسيد': 100,
#  'جينيرا': 100,
#  'اوكساليبتال': 100,
#  'سيريلاك': 100,
#  'اوكاربون': 100,
#  'اكتينون': 100,
#  'بروزاك': 100,
#  'اكساميد': 100,
#  'وينديبين': 100,
#  'بريليك': 100,
#  'نازونكس': 100,
#  'ايموكسكلاف': 100,
#  'كوديلاترول': 100,
#  'كوباد': 100,
#  'نكتاليا': 100,
#  'دوليبران': 100,
#  'اليمبوسيس': 100,
#  'محلول': 100,
#  'تريتاس': 100,
#  'زولادكس': 100,
#  'مومينتا': 100,
#  'سبازمو': 100,
#  'انتروجرمينا': 100,
#  'فلوكا': 100,
#  'سيفترياكسون': 100,
#  'بيتادين': 100,
#  'اوبلكس': 100,
#  'يونيكتام': 100,
#  'باوريكتا': 100,
#  'دوستينكس': 100,
#  'فياجرا': 100,
#  'افيروزوليد': 100,
#  'فوناسبير': 100,
#  'سيلدافا': 100,
#  'سيبروديازول': 100,
#  'اولفنت': 100,
#  'اوميجا': 100,
#  'يوريفين': 100,
#  'فنجيكان': 100,
#  'برايم': 100,
#  'فارماكتيف': 100,
#  'سولفاكس': 100,
#  'بيوتين': 100,
#  'دانتريلاكس': 100,
#  'جاتيستار': 100,
#  'ديامونركتا': 100,
#  'لوفير': 100,
#  'زوركال': 100,
#  'لاميكتال': 100,
#  'ديجليفلوز': 100,
#  'سومازينا': 100,
#  'سيلجون': 100,
#  'بلوكاتنس': 100,
#  'سبازمورست': 100,
#  'فوليكاب': 100,
#  'تيكافير': 100,
#  'سينوبريل': 100,
#  'اورسوفالك': 100,
#  'فلاكورت': 100,
#  'جليكودال': 100,
#  'سايميدل': 100,
#  'اكتوفنت': 100,
#  'ايفيروسبان': 100,
#  'اوركاديكسولين': 100,
#  'فاروفيجا': 100,
#  'برافاماكس': 100,
#  'فليكتور': 100,
#  'ايبانتين': 100,
#  'ديبرام': 100,
#  'تريفاستال': 100,
#  'ويلمان': 100,
#  'دياسيرين': 100,
#  'زيثرون': 100,
#  'لاميفين': 100,
#  'ديفيدو': 100,
#  'جلوكوفاج': 100,
#  'ريسباتيو': 100,
#  'ايريوس': 100,
#  'هيرتونيك': 100,
#  'تافاسين': 100,
#  'شاي': 100,
#  'اميجراويست': 100,
#  'تريسيبا': 100,
#  'باي': 100,
#  'ديسبركام': 100,
#  'ايروكسول': 100,
#  'بيونال': 100,
#  'هيليكيور': 100,
#  'كيتوفان': 100,
#  'الدوميت': 100,
#  'ديكساميثازون': 100,
#  'كوردارون': 100,
#  'اليفو': 100,
#  'فينادون': 100,
#  'فورسيجا': 100,
#  'بلافيكس': 100,
#  'تافانيك': 100,
#  'بدياشور': 100,
#  'سكارو': 100,
#  'تامسولين': 100,
#  'جينوكونازول': 100,
#  'فابوزول': 100,
#  'كروميوم': 100,
#  'جينوفيل': 100,
#  'ديكسافلوكس': 100,
#  'صوديوم': 100,
#  'جاناتون': 100,
#  'سيبراليكس': 100,
#  'الوكيتا': 100,
#  'فايركتا': 100,
#  'اماريل': 100,
#  'ابيكسيدون': 100,
#  'بلوم': 100,
#  'ليمتلس': 100,
#  'فافرين': 100,
#  'تارجوفلوكسين': 100,
#  'كارنيفيتا': 100,
#  'ادابالين': 100,
#  'افيل': 100,
#  'بروستريد': 100,
#  'هاي': 100,
#  'مويست': 100,
#  'شوجارلو': 100,
#  'تارج': 100,
#  'كيتوستريل': 100,
#  'ميبو': 100,
#  'بيتميجا': 100,
#  'زنك': 100,
#  'تيراتام': 100,
#  'تورسيريتك': 100,
#  'ميتاكارديا': 100,
#  'دياكيوريماب': 100,
#  'تجريتول': 100,
#  'ايزاكارد': 100,
#  'هيموجيت': 100,
#  'البافيت': 100,
#  'ايزوتريتينوين': 100,
#  'توسيفان': 100,
#  'جابيماش': 100,
#  'موفينتور': 100,
#  'كلاسيد': 100,
#  'ابيكوبرد': 100,
#  'برناسورس': 100,
#  'فاستافلام': 100,
#  'اوميز': 100,
#  'املوديبين': 100,
#  'جلوكوز': 100,
#  'لاسيكس': 100,
#  'لوبريكاف': 100,
#  'الجزال': 100,
#  'ميجافين': 100,
#  'فيوسيكورت': 100,
#  'الفانوفا': 100,
#  'الكابرايد': 100,
#  'ديفلوكان': 100,
#  'ديودارت': 100,
#  'ريبلس': 100,
#  'اريك': 100,
#  'ماكسيلاز': 100,
#  'سيستان': 100,
#  'ريزوديج': 100,
#  'دوسباتالين': 100,
#  'سبانيلا': 100,
#  'كلوزابكس': 100,
#  'بتك': 100,
#  'زيستريل': 100,
#  'فاكتو': 100,
#  'بترو': 100,
#  'انتودين': 100,
#  'فيسرالجين': 100,
#  'كارباميد': 100,
#  'ميكستارد': 100,
#  'توينزول': 100,
#  'سيريتايد': 100,
#  'كورتيبليكس': 100,
#  'جالفس': 100,
#  'الفافيم': 100,
#  'فيافاج': 100,
#  'فلوبادكس': 100,
#  'اجركس': 100,
#  'ريفاروسبير': 100,
#  'سيتراك': 100,
#  'كانزارتان': 100,
#  'فرتيتونكس': 100,
#  'كروميترون': 100,
#  'لينكس': 100,
#  'سيمباتكس': 100,
#  'جوسبرين': 100,
#  'فلاجيل': 100,
#  'سيتابرونكس': 100,
#  'ابيدون': 100,
#  'بيوفيت': 100,
#  'الفينترن': 100,
#  'ميرالجو': 100,
#  'سيالس': 100,
#  'ديكلوفين': 100,
#  'لانتوس': 100,
#  'ارث': 100,
#  'ديكسازون': 100,
#  'ليليبيل': 100,
#  'فورموهال': 100,
#  'فورتيموكس': 100,
#  'دولوكسبرين': 100,
#  'ديكابرينو': 100,
#  'دوجماتيل': 100,
#  'دافلون': 100,
#  'سلفستر': 100,
#  'بيرفورما': 100,
#  'مونوماك': 100,
#  'ميجاموكس': 100,
#  'فليكس': 100,
#  'بانتولوك': 100,
#  'بيبيلاك': 100,
#  'كويتابكس': 100,
#  'دينستين': 100,
#  'كونفنتين': 100,
#  'اكس': 100,
#  'زيثروسين': 100,
#  'دوفاستون': 100,
#  'سيرفيتام': 100,
#  'فيلداجلوز': 100,
#  'فيدروب': 100,
#  'بيرفكت': 100,
#  'سالبوفنت': 100,
#  'دوروفين': 100,
#  'زيلون': 100,
#  'بريستو': 100,
#  'فورفلوزين': 100,
#  'سيفاكسون': 100,
#  'كالسيوم': 100,
#  'يوروسولفين': 100,
#  'هيدروفيرين': 100,
#  'ايزيس': 100,
#  'برونتوجيست': 100,
#  'تاروليمس': 100,
#  'ليدوكاين': 100,
#  'فلورست': 100,
#  'فليكسوفان': 100,
#  'سريبروليسين': 100,
#  'انكونت': 100,
#  'هيستازين': 100,
#  'دلتافيت': 100,
#  'اورليستات': 100,
#  'بوليمير': 100,
#  'ديفاكوت': 100,
#  'مافيلور': 100,
#  'فيتامين': 100,
#  'سيمبيكورت': 100,
#  'ماكرو': 100,
#  'اليكا': 100,
#  'براديبيكت': 100,
#  'دنتينوكس': 100,
#  'جراليبنتين': 100,
#  'ثرومبكس': 100,
#  'اميبرايد': 100,
#  'كوبال': 100,
#  'تريب': 100,
#  'بيبانثين': 100,
#  'ميرتيماش': 100,
#  'كتافلام': 100,
#  'ترنتال': 100,
#  'فلاكسوبرايد': 100,
#  'اوبتامينس': 100,
#  'سينجاردي': 100,
#  'زيثروماكس': 100,
#  'تلفاست': 100,
#  'جولد': 100,
#  'كاندلكان': 100,
#  'اكتومثرين': 100,
#  'كونكور': 100,
#  'كلاريتين': 100,
#  'فوراديل': 100,
#  'اديمكس': 100,
#  'ديفلوستيرو': 100,
#  'ماء': 100,
#  'بيسكالدين': 100,
#  'ميثايلتكنو': 100,
#  'اكسفورج': 100,
#  'ازيلاست': 100,
#  'اناليرج': 100,
#  'لاري': 100,
#  'سنترم': 100,
#  'بالميكورت': 100,
#  'توب': 100,
#  'ديكلوبرو': 100,
#  'فيتاسيد': 100,
#  'يوريكونترول': 100,
#  'اوجمنتين': 100,
#  'هيربانا': 100,
#  'فيرسيرك': 100,
#  'اورلي': 100,
#  'دايجينورم': 100,
#  'ميوكوفيلين': 100,
#  'ميراج': 100,
#  'لوبريفيسك': 100,
#  'ايتوماش': 100,
#  'اوندالينز': 100,
#  'رجكور': 100,
#  'جابتن': 100,
#  'تراجينتا': 100,
#  'زيرتيك': 100,
#  'زيثروكان': 100,
#  'ساكسندا': 100,
#  'جانوميت': 100,
#  'نيكسيكيور': 100,
#  'بيفاتراسين': 100,
#  'التراكاين': 100,
#  'بريدسول': 100,
#  'تيرز': 100,
#  'ريكوكسيبرايت': 100,
#  'ستاركوبريكس': 100,
#  'بيبزول': 100,
#  'مونوريل': 100,
#  'اسبرين': 100,
#  'الكابريس': 100,
#  'ايمباكوزا': 100,
#  'اوكيوجارد': 100,
#  'كال': 100,
#  'كيبرا': 100,
#  'مينوكسيلوك': 100,
#  'فيمارا': 100,
#  'دلتارينو': 100,
#  'ليمتليس': 100,
#  'ديمرا': 100,
#  'اليكاسال': 100,
#  'رينكس': 100,
#  'فبيوريك': 100,
#  'بيرفيكتيل': 100,
#  'ستروكا': 100,
#  'اليكويس': 100,
#  'اوكتاترون': 100,
#  'سوماتروبين': 100,
#  'نكسيام': 100,
#  'ابيمول': 100,
#  'انشور': 100,
#  'توبمود': 100,
#  'سبيكتون': 100,
#  'بايولجام': 100,
#  'فلوموكس': 100,
#  'اندرال': 100,
#  'استوهالت': 100,
#  'تولانجو': 100,
#  'اوروفكس': 100,
#  'اسبوسيد': 100,
#  'ديافلوزيمت': 100,
#  'ايسوبتن': 100,
#  'افيميو': 100,
#  'سولوفريش': 100,
#  'دورميفال': 100,
#  'تيبونينا': 100,
#  'كولوفيرين': 100,
#  'اكوا': 100,
#  'ازجوفانس': 100,
#  'زوفيراكس': 100,
#  'كلوباترا': 100,
#  'نيورونتين': 100,
#  'الزميندا': 100,
#  'توسكان': 100,
#  'ديورجوي': 100,
#  'سيلينيوم': 100,
#  'ديبروساليك': 100,
#  'كابرون': 100,
#  'دالاسين': 100,
#  'سيلوكينزوك': 100,
#  'ميوكوستا': 100,
#  'زنكترون': 100,
#  'بيبون': 100,
#  'اتوريزا': 100,
#  'كلوبكس': 100,
#  'كلافيموكس': 100,
#  'توسيستوب': 100,
#  'اوستيوكير': 100,
#  'ايزابريل': 100,
#  'تكلو': 100,
#  'اريسبت': 100,
#  'فنتال': 100,
#  'اميولانت': 100,
#  'سوبراكس': 100,
#  'نورجيسيك': 100,
#  'ريجين': 100,
#  'بروكسيمول': 100,
#  'بولي': 100,
#  'دايت': 100,
#  'اميونو': 100,
#  'ميلجا': 100,
#  'فولتارين': 100,
#  'سيريبروماب': 100,
#  'فوميبريك': 100,
#  'ديلاترول': 100,
#  'تراي': 100,
#  'ايبوتين': 100,
#  'فاستاريل': 100,
#  'لازيلاكتون': 100,
#  'جليسرين': 100,
#  'اوتريفين': 100,
#  'سيتال': 100,
#  'رومارين': 100,
#  'كيريلا': 100,
#  'سوفيناسين': 100,
#  'بيتاسيرك': 100,
#  'لوسترال': 100,
#  'بيرفيكتوديل': 100,
#  'تاريفيد': 100,
#  'ابيكوتيل': 100,
#  'فيتاستريس': 100,
#  'بيبرا': 100,
#  'فلاجيلات': 100,
#  'بينوكس': 100,
#  'بليتال': 100,
#  'ستربتوكين': 100,
#  'ستربسلز': 100,
#  'توبرين': 100,
#  'زيرتك': 100,
#  'داباجليف': 100,
#  'كالدين': 100,
#  'نيوروتون': 100,
#  'نيوروفيت': 100,
#  'سيردالود': 100,
#  'زوراكسون': 100,
#  'سوابيفنت': 100,
#  'زيجدو': 100,
#  'ديكلاك': 100,
#  'رويال': 100,
#  'ريلاكسون': 100,
#  'نوتوسيل': 100,
#  'ميكروسيرك': 100,
#  'افيفافاسك': 100,
#  'اكسارونت': 100,
#  'سويتال': 100,
#  'نورمو': 100,
#  'كتافاست': 100,
#  'ديكساتوبرين': 100,
#  'اومنيفورا': 100,
#  'فاستل': 100,
#  'سانسو': 100,
#  'داونوبرازول': 100,
#  'ميوكوتك': 100,
#  'افيكسور': 100,
#  'فليكسونيز': 100,
#  'بانثينول': 100,
#  'جانوفيا': 100,
#  'بارامول': 100,
#  'ستارفيل': 100,
#  'سليبيز': 100,
#  'فوربيودس': 100,
#  'دافاليندي': 100,
#  'دابوكستارد': 100,
#  'كالسيترون': 100,
#  'كولد': 100,
#  'بكتي': 100,
#  'فوناسيدان': 100,
#  'افوصويا': 100,
#  'اركوكسيا': 100,
#  'البندازول': 100,
#  'نانازوكسيد': 100,
#  'جينوزول': 100,
#  'ريفارست': 100,
#  'انجيكتمول': 100,
#  'ليفسيت': 100,
#  'اوزمبك': 100,
#  'ميليتوفكس': 100,
#  'كروماكس': 100,
#  'دياميكرون': 100,
#  'اولفين': 100,
#  'ديبوفيت': 100,
#  'نايت': 100,
#  'بريمبران': 100,
#  'راني': 100,
#  'ليفابيون': 100,
#  'اماجلوست': 100,
#  'ماريفان': 100,
#  'دوفالاك': 100,
#  'رجيماكس': 100,
#  'ازماتك': 100,
#  'فينتوكف': 100,
#  'سيبتازول': 100,
#  'ابيدرا': 100,
#  'ليبيتور': 100,
#  'بروكورلان': 100,
#  'جستيكول': 100,
#  'ناتريليكس': 100,
#  'داونستيرولين': 100,
#  'جارديانس': 100,
#  'ايميرست': 100,
#  'شان': 100,
#  'بلينك': 100,
#  'سيبرا': 100,
#  'فوار': 100,
#  'ويست': 100,
#  'جاست': 100,
#  'ايموكس': 100,
#  'ازموراب': 100,
#  'زنكوديرم': 100,
#  'دوكسيرازول': 100,
#  'اومنيك': 100,
#  'اورسو': 100,
#  'بريمونيدين': 100,
#  'ايفرزين': 100,
#  'برافوتين': 100,
#  'نوستامين': 100,
#  'جاستروبيوتك': 100,
#  'كونترولوك': 100,
#  'بيكوزيم': 100,
#  'كليكسان': 100,
#  'ديفاورل': 100,
#  'زولامول': 100,
#  'كونجيستال': 100,
#  'سيلونا': 100,
#  'موتيليوم': 100,
#  'فيتاترون': 100,
#  'ايزوجاست': 100,
#  'فيروترون': 100,
#  'ميلوكين': 100,
#  'اليربان': 100,
#  'ديكانسيت': 100,
#  'بانتوجار': 100,
#  'التيازيم': 100,
#  'نوفيستوريك': 100,
#  'دوكسيوم': 100,
#  'نيزابيكس': 100,
#  'ايراستابكس': 100,
#  'بروفين': 100,
#  'فلدين': 100,
#  'كيورام': 100,
#  'سيستون': 100,
#  'اريكتاليس': 100,
#  'وانتوثري': 100}

# %%
from Levenshtein import distance as levenshtein_distance

def suggest_corrections(misspelled_word, top_n=1, max_distance=3):
    suggestions = []
    for word in word_freq_dict:
        # Calculate edit distance between the misspelled word and the product name
        edit_dist = levenshtein_distance(misspelled_word, word)
        if edit_dist <= max_distance:
            suggestions.append((word, word_freq_dict[word], edit_dist))
    # Sort suggestions by edit distance and frequency
    suggestions.sort(key=lambda x: (x[2], -x[1]))
    return suggestions[0][0] if suggestions else misspelled_word
    
# Example usage
misspelled_word = "فلكسوفان"
corrections = suggest_corrections(misspelled_word, word_freq_dict)
print(f"Suggestions for '{misspelled_word}': {corrections}")
# Out:
# Suggestions for 'فلكسوفان': فليكسوفان

# %%
from wordfreq import word_frequency, top_n_list
from collections import defaultdict

# Get the top N most frequent Arabic words
top_arabic_words = top_n_list('ar', 100000)  # Adjust the number as needed

# Create a frequency dictionary
word_freq_dict = {word: word_frequency(word, 'ar') for word in master_product_words}

# Function to suggest corrections for a misspelled word
def suggest_corrections(misspelled_word, word_freq_dict, top_n=5):
    suggestions = []
    for word in word_freq_dict:
        if word.startswith(misspelled_word[0]):  # Simple heuristic: same starting letter
            suggestions.append((word, word_freq_dict[word]))
    # Sort suggestions by frequency (higher frequency first)
    suggestions.sort(key=lambda x: x[1], reverse=True)
    return [word for word, freq in suggestions[:top_n]]

# Example usage
misspelled_word = "فلكسوفان"
corrections = suggest_corrections(misspelled_word, word_freq_dict)
print(f"Suggestions for '{misspelled_word}': {corrections}")
# Out:
# Suggestions for 'فلكسوفان': ['فيلم', 'فيل', 'فلو', 'فيتامين', 'فورت']

# %%
def fix_misspelled_words_in_string(input_string, max_distance=3):
    """
    Fix misspelled words in a string while leaving correctly spelled words unchanged.
    """
    # Tokenize the input string into words
    words = input_string.split()
    
    # Correct each word if it is misspelled
    corrected_words = []
    for word in words:
        # Check if the word is in the frequency dictionary (assume it's correct if it is)
        if word in word_freq_dict:
            corrected_words.append(word)
        else:
            # If the word is not in the dictionary, suggest a correction
            corrected_word = suggest_corrections(word, word_freq_dict, max_distance)
            # If suggestions are returned, take the first one
            if corrected_word:
                corrected_words.append(corrected_word[0])
            else:
                corrected_words.append(word)
    
    # Reconstruct the string
    corrected_string = ' '.join(corrected_words)
    return corrected_string

dataset_df['seller_item_name_clean_spell'] = dataset_df['seller_item_name_clean'].apply(lambda x: fix_misspelled_words_in_string(str(x)))

# %%
fix_misspelled_words_in_string("اوندالينزا 4 مجم كبسول")
# Out:
# 'ان 4 مجم كبسول'

# %%
dataset_df.sample(10)
# Out:
#         sku         marketplace_product_name_ar  \
# 24361  4403                  دوزين 1 مجم 20 قرص
# 71389  1631               افيميو قطرة عين 10 مل
# 53921  2082          بينوكس 0.4% قطرة عين 10 مل
# 35446  2696              اتورستات 40 مجم 14 قرص
# 62596   478  سيريتايد ديسكس 250/50 مكجم 60 جرعة
# 69945    84               اوميز 20 مجم 14 كبسول
# 35975  3586      ميليتوفكس مت 5/1000 مجم 30 قرص
# 69580   744               كيتولاك 10 مجم 20 قرص
# 63424    53                زيثرون 500 مجم 5 قرص
# 40689  1863                ستروكا 75 مجم 30 قرص
#
#                          seller_item_name  price     seller_item_name_clean  \
# 24361        دوزين 1مجم اقراص سعر 14 جنيه   14.0  دوزين 1 مجم كبسول 14 جنيه
# 71389                  ايفيميو قطرة للعين   44.0          ايفيميو قطره لعين
# 53921                          بينوكس نقط   23.0                 بينوكس نقط
# 35446              اتورستات 40 م 14 قرص د   76.0       اتورستات 40 14 كبسول
# 62596          سيريتيد 250 ديسكس 60جرعة**  257.0  سيريتيد 250 ديسكس 60 جرعه
# 69945        اوميز 20مجم 14كبسول سعر جديد   56.0      اوميز 20 مجم 14 كبسول
# 35975  MELLITOFIX MET 5MG/ 1000 MG 30 TAB  163.5                  5 1000 30
# 69580        كيتولاك 10مج20ق س ج/العامرية   38.0  كيتولاك 10 مج 20 العامريه
# 63424               زيثرون 500  -5قرص س ج   86.0         زيثرون 500 5 كبسول
# 40689                   ستروكا اقراص/ابكس  145.0          ستروكا كبسول ابكس
#
#       seller_item_name_clean_spell
# 24361      دوزين 1 مجم كبسول 14 جي
# 71389                 ان قطره لعين
# 53921                   بينوكس نقط
# 35446         اتورستات 40 14 كبسول
# 62596         سي 250 ديسكس 60 جرعه
# 69945        اوميز 20 مجم 14 كبسول
# 35975                    5 1000 30
# 69580    كيتولاك 10 مج 20 العامريه
# 63424           زيثرون 500 5 كبسول
# 40689              ستروكا كبسول ان

# %%
def extract_and_filter_words(text):
    # Use regex to find all words (excluding numbers)
    words = re.findall(r'\b[^\d\W]+\b', text)
    # Filter out words with fewer than 3 letters
    return [word for word in words if len(word) >= 3]

# Apply the function to the 'product_name_ar' column
all_words = master_df['product_name_ar'].apply(extract_and_filter_words).explode().dropna().tolist()

# %%
print(len(all_words))
all_words
# Out:
# 3099
# ['انافرونيل',
#  'مجم',
#  'قرص',
#  'لوبريكاف',
#  'شراب',
#  'تومكس',
#  'بلس',
#  'قرص',
#  'تاروليمس',
#  'مرهم',
#  'جليبتس',
#  'بلس',
#  'مجم',
#  'قرص',
#  'دالاسين',
#  'مجم',
#  'كبسول',
#  'باي',
#  'بروفينيد',
#  'مجم',
#  'قرص',
#  'باي',
#  'كيتوجيسيك',
#  'مجم',
#  'قرص',
#  'بروتوفيكس',
#  'مجم',
#  'قرص',
#  'ارثروفاست',
#  'مجم',
#  'قرص',
#  'ارث',
#  'فرى',
#  'مجم',
#  'قرص',
#  'انافرونيل',
#  'مجم',
#  'قرص',
#  'فليكتور',
#  'مجم',
#  'كبسول',
#  'ديباكين',
#  'مجم',
#  'محلول',
#  'بالفم',
#  'بانتازول',
#  'مجم',
#  'قرص',
#  'اتاكاند',
#  'مجم',
#  'قرص',
#  'هيموجيت',
#  'مجم',
#  'شراب',
#  'ليليبيل',
#  'مجم',
#  'قرص',
#  'موديوريتك',
#  'مجم',
#  'قرص',
#  'اميلو',
#  'مجم',
#  'قرص',
#  'اتورستات',
#  'مجم',
#  'قرص',
#  'كيريلا',
#  'مرهم',
#  'كروميوم',
#  'ميباكو',
#  'كبسول',
#  'البندازول',
#  'مجم',
#  'قرص',
#  'نافوبروكسين',
#  'مجم',
#  'اقماع',
#  'توبمود',
#  'مجم',
#  'كبسولة',
#  'ديكلاك',
#  'مجم',
#  'قرص',
#  'التراكايين',
#  'جيل',
#  'كولوفيرين',
#  'قرص',
#  'فيروجلوبين',
#  'شراب',
#  'ميلجا',
#  'قرص',
#  'بلافيكس',
#  'مجم',
#  'قرص',
#  'بانادول',
#  'اكسترا',
#  'قرص',
#  'فيروجلوبين',
#  'كبسول',
#  'كونفنتين',
#  'مجم',
#  'كبسول',
#  'ديبوفيت',
#  'مكجم',
#  'امبول',
#  'اريك',
#  'مجم',
#  'قرص',
#  'باي',
#  'الكوفان',
#  'مجم',
#  'قرص',
#  'كتافلام',
#  'مجم',
#  'قرص',
#  'اوميجا',
#  'بلس',
#  'كبسولة',
#  'كونفنتين',
#  'مجم',
#  'كبسولة',
#  'كتافاست',
#  'مجم',
#  'كيس',
#  'امبيزيم',
#  'قرص',
#  'زيثرون',
#  'مجم',
#  'قرص',
#  'ديكساميثازون',
#  'العامرية',
#  'مجم',
#  'امبول',
#  'بيفاتراسين',
#  'سبراى',
#  'برافوتين',
#  'مجم',
#  'كيس',
#  'تافانيك',
#  'محم',
#  'قرص',
#  'دوروفين',
#  'كبسولة',
#  'ديكساميثازون',
#  'المهن',
#  'مجم',
#  'امبول',
#  'فوار',
#  'فروت',
#  'كيس',
#  'جابتن',
#  'مجم',
#  'كبسولة',
#  'اوبلكس',
#  'شراب',
#  'فياجرا',
#  'مجم',
#  'اقراص',
#  'سبازمو',
#  'ديجستين',
#  'قرص',
#  'ديمرا',
#  'قرص',
#  'بانتولوك',
#  'مجم',
#  'قرص',
#  'اوندالينز',
#  'مجم',
#  'فيلم',
#  'سريع',
#  'الذوبان',
#  'بالفم',
#  'كولوفيرين',
#  'قرص',
#  'سيلجون',
#  'مجم',
#  'قرص',
#  'فيدروب',
#  'وحدة',
#  'دولية',
#  'نقط',
#  'بالفم',
#  'ريكوكسيبرايت',
#  'مجم',
#  'قرص',
#  'ثيوتاسيد',
#  'مركب',
#  'كبسول',
#  'ماكسيلاز',
#  'شراب',
#  'ازموراب',
#  'مجم',
#  'كبسول',
#  'اليكويس',
#  'مجم',
#  'قرص',
#  'فيروترون',
#  'كبسول',
#  'لاسيكس',
#  'امبول',
#  'زيثروكان',
#  'مجم',
#  'كبسولة',
#  'برونشيكم',
#  'اليكسر',
#  'شراب',
#  'اوتريفين',
#  'نقط',
#  'انف',
#  'للكبار',
#  'بانادول',
#  'كولد',
#  'آند',
#  'فلو',
#  'داي',
#  'قرص',
#  'اولفنت',
#  'شراب',
#  'ملل',
#  'كلاريتين',
#  'مجم',
#  'قرص',
#  'دوليبران',
#  'مجم',
#  'قرص',
#  'فنتال',
#  'مركب',
#  'بخاخ',
#  'طرق',
#  'الفم',
#  'جرعة',
#  'جابتن',
#  'مجم',
#  'كبسولة',
#  'فلاجيل',
#  'مجم',
#  'قرص',
#  'تلفاست',
#  'شراب',
#  'معلق',
#  'سيتال',
#  'شراب',
#  'معلق',
#  'اوكاربون',
#  'قرص',
#  'اماريل',
#  'مجم',
#  'قرص',
#  'هاي',
#  'فريش',
#  'قطرة',
#  'عين',
#  'تلفاست',
#  'مجم',
#  'قرص',
#  'اتور',
#  'مجم',
#  'قرص',
#  'ميوكوستا',
#  'مجم',
#  'قرص',
#  'كتافلام',
#  'مجم',
#  'امبول',
#  'باوريكتا',
#  'مجم',
#  'قرص',
#  'جابيماش',
#  'مجم',
#  'قرص',
#  'افيل',
#  'مجم',
#  'امبول',
#  'عضل',
#  'كلوبكس',
#  'مجم',
#  'قرص',
#  'اماريل',
#  'قرص',
#  'سايميدل',
#  'شراب',
#  'مستحلب',
#  'ديامونركتا',
#  'مجم',
#  'قرص',
#  'دوفالاك',
#  'شراب',
#  'ريفاروسبير',
#  'مجم',
#  'قرص',
#  'نوستامين',
#  'قطرة',
#  'لوفير',
#  'مجم',
#  'قرص',
#  'اتور',
#  'مجم',
#  'قرص',
#  'جينوزول',
#  'كريم',
#  'مهبلي',
#  'نازاكورت',
#  'بخاخ',
#  'بالأنف',
#  'جرعة',
#  'جولد',
#  'بلس',
#  'غسول',
#  'مهبلي',
#  'تافاسين',
#  'مجم',
#  'قرص',
#  'كولوفاتيل',
#  'قرص',
#  'كوبال',
#  'مكجم',
#  'قرص',
#  'اكساميد',
#  'مجم',
#  'قرص',
#  'فيرسيرك',
#  'مجم',
#  'قرص',
#  'ناتريليكس',
#  'مجم',
#  'قرص',
#  'نانازوكسيد',
#  'مجم',
#  'قرص',
#  'ايميرست',
#  'مجم',
#  'امبول',
#  'اولابكس',
#  'مجم',
#  'قرص',
#  'فيبراميسين',
#  'مجم',
#  'كبسولات',
#  'كورتيبليكس',
#  'للاطفال',
#  'امبول',
#  'لوسترال',
#  'مجم',
#  'قرص',
#  'بليجيكا',
#  'قطرة',
#  'عين',
#  'اوتريفين',
#  'نقط',
#  'أنف',
#  'للأطفال',
#  'كارنيتين',
#  'بلس',
#  'قرص',
#  'سنجيولير',
#  'مجم',
#  'قرص',
#  'إندرال',
#  'مجم',
#  'قرص',
#  'امريزول',
#  'مجم',
#  'قرص',
#  'ميلوكين',
#  'كريم',
#  'شوجارلو',
#  'بلس',
#  'مجم',
#  'قرص',
#  'زيرتيك',
#  'شراب',
#  'نيزابيكس',
#  'شامبو',
#  'جوسبرين',
#  'مجم',
#  'قرص',
#  'بيونال',
#  'كبسولة',
#  'فليكسونيز',
#  'بخاخة',
#  'للانف',
#  'جرعة',
#  'روتاسي',
#  'اقراص',
#  'الجزال',
#  'كريم',
#  'فاستافلام',
#  'مجم',
#  'قرص',
#  'جابتن',
#  'مجم',
#  'كبسولة',
#  'كارنيتين',
#  'كبسولة',
#  'زيثروماكس',
#  'شراب',
#  'معلق',
#  'فوليك',
#  'اسيد',
#  'ميباكو',
#  'مكجم',
#  'قرص',
#  'سويتال',
#  'كيس',
#  'ليفوهيستام',
#  'شراب',
#  'دولفين',
#  'مجم',
#  'أقماع',
#  'افيميو',
#  'قطرة',
#  'عين',
#  'فلورست',
#  'قرص',
#  'لاسيكس',
#  'قرص',
#  'توسيستوب',
#  'شراب',
#  'ريكوكسيبرايت',
#  'مجم',
#  'قرص',
#  'ابيكسيدون',
#  'مجم',
#  'قرص',
#  'ستيرونات',
#  'مجم',
#  'قرص',
#  'فليكس',
#  'مكجم',
#  'جرعة',
#  'بخاخ',
#  'للانف',
#  'توسيفان',
#  'شراب',
#  'ابيمول',
#  'مجم',
#  'قرص',
#  'دياميكرون',
#  'مجم',
#  'قرص',
#  'جليميبرايد',
#  'بلس',
#  'مجم',
#  'قرص',
#  'توينزول',
#  'قطرة',
#  'للعين',
#  'بريمونيدين',
#  'قطرة',
#  'عين',
#  'زيرتك',
#  'نقط',
#  'بالفم',
#  'نانازوكسيد',
#  'شراب',
#  'معلق',
#  'ايفيبرونت',
#  'شراب',
#  'الكابريس',
#  'مجم',
#  'قرص',
#  'ابيكسيدون',
#  'مجم',
#  'قرص',
#  'دايجيست',
#  'ايزى',
#  'كبسول',
#  'سلفستر',
#  'كبسول',
#  'انكونت',
#  'ايه',
#  'مجم',
#  'قرص',
#  'كولوماك',
#  'محلول',
#  'موضعى',
#  'ايبانتين',
#  'مجم',
#  'كبسول',
#  'سالبوفنت',
#  'مجم',
#  'شراب',
#  'ابيكسيدون',
#  'مجم',
#  'قرص',
#  'بيتاديرم',
#  'مرهم',
#  'تريتاس',
#  'بروتكت',
#  'مجم',
#  'قرص',
#  'ماء',
#  'غريب',
#  'بامبينو',
#  'شراب',
#  'تريفاستال',
#  'ريتارد',
#  'مجم',
#  'قرص',
#  'ادابالين',
#  'جيل',
#  'اتورستات',
#  'مجم',
#  'قرص',
#  'ماريفان',
#  'مجم',
#  'قرص',
#  'الكابريس',
#  'بلس',
#  'قرص',
#  'ابيكسيدون',
#  'شراب',
#  'ريموواكس',
#  'نقط',
#  'للاذن',
#  'رجكور',
#  'مجم',
#  'قرص',
#  'ماكسيكال',
#  'شراب',
#  'دايت',
#  'سويت',
#  'قرص',
#  'بترو',
#  'قرص',
#  'جينوكونازول',
#  'كريم',
#  'مهبلي',
#  'اتورستات',
#  'مجم',
#  'قرص',
#  'ابل',
#  'لايت',
#  'قرص',
#  'املوديبين',
#  'مجم',
#  'قرص',
#  'فيلداجلوز',
#  'بلس',
#  'مجم',
#  'قرص',
#  'زوركال',
#  'مجم',
#  'قرص',
#  'رينكس',
#  'نقط',
#  'أنف',
#  'للكبار',
#  'دايجينورم',
#  'شراب',
#  'نيوروفيت',
#  'قرص',
#  'دوفاستون',
#  'مجم',
#  'قرص',
#  'ريفاروسبير',
#  'مجم',
#  'قرص',
#  'فيلدافورمين',
#  'مجم',
#  'قرص',
#  'دولسيل',
#  'مجم',
#  'قرص',
#  'فيت',
#  'نقط',
#  'مللى',
#  'اوميز',
#  'مجم',
#  'كبسول',
#  'نورمو',
#  'تيرز',
#  'قطرة',
#  'عين',
#  'فلدين',
#  'مجم',
#  'امبول',
#  'عضل',
#  'برافوتين',
#  'مجم',
#  'كيس',
#  'نورجيسيك',
#  'قرص',
#  'تامسولين',
#  'بلس',
#  'مجم',
#  'قرص',
#  'ممتد',
#  'المفعول',
#  'إندرال',
#  'مجم',
#  'قرص',
#  'بيتولفكس',
#  'امبول',
#  'عضل',
#  'كريستوليب',
#  'مجم',
#  'قرص',
#  'دانتريلاكس',
#  'مجم',
#  'كبسولة',
#  'ليفوهيستام',
#  'مجم',
#  'قرص',
#  'بريمبران',
#  'مجم',
#  'امبول',
#  'اوميز',
#  'مجم',
#  'كبسولة',
#  'دابوكستارد',
#  'مجم',
#  'قرص',
#  'كيتولاك',
#  'مجم',
#  'امبول',
#  'دوسباتالين',
#  'ريتارد',
#  'مجم',
#  'كبسول',
#  'فوميبريك',
#  'مجم',
#  'قرص',
#  'ممتد',
#  'المفعول',
#  'كولونا',
#  'قرص',
#  'سليبريكس',
#  'مجم',
#  'كبسولة',
#  'سيلدافا',
#  'مجم',
#  'قرص',
#  'تلفاست',
#  'مجم',
#  'قرص',
#  'تيرز',
#  'جارد',
#  'قطرة',
#  'عين',
#  'ايراستابكس',
#  'تريو',
#  'مجم',
#  'قرص',
#  'دانست',
#  'مجم',
#  'امبول',
#  'فاروفيجا',
#  'مجم',
#  'قرص',
#  'اماريل',
#  'مجم',
#  'قرص',
#  'انتوبرال',
#  'مجم',
#  'قرص',
#  'اوكتاترون',
#  'كبسول',
#  'ستاركوبريكس',
#  'مجم',
#  'قرص',
#  'نيكسيكيور',
#  'مجم',
#  'قرص',
#  'دلتارينو',
#  'بخاخ',
#  'بالأنف',
#  'تراى',
#  'امبول',
#  'اولفين',
#  'مجم',
#  'امبول',
#  'كوبال',
#  'مكجم',
#  'قرص',
#  'دانست',
#  'مجم',
#  'امبول',
#  'كارنيتين',
#  'مجم',
#  'شراب',
#  'سيمباتكس',
#  'مجم',
#  'كبسول',
#  'داونوبرازول',
#  'مجم',
#  'كبسول',
#  'سبيكتون',
#  'مجم',
#  'قرص',
#  'كونترولوك',
#  'مجم',
#  'قرص',
#  'تيراتام',
#  'اكس',
#  'مجم',
#  'قرص',
#  'كارباميد',
#  'ممفيس',
#  'كريم',
#  'بيبرا',
#  'مجم',
#  'قرص',
#  'تاريفيد',
#  'مجم',
#  'قرص',
#  'كارنيفيتا',
#  'فورت',
#  'قرص',
#  'دلتافيت',
#  'مجم',
#  'قرص',
#  'تحت',
#  'اللسان',
#  'بيسكالدين',
#  'مجم',
#  'كبسول',
#  'سولوفريش',
#  'قطرة',
#  'عين',
#  'ايمباكوزا',
#  'مجم',
#  'قرص',
#  'فورتيموكس',
#  'مجم',
#  'قطرة',
#  'عين',
#  'بليتال',
#  'مجم',
#  'قرص',
#  'ديكسافلوكس',
#  'قطرة',
#  'عين',
#  'بانتولوك',
#  'مجم',
#  'قرص',
#  'كوردارون',
#  'مجم',
#  'قرص',
#  'الفانوفا',
#  'قطرة',
#  'عين',
#  'نيتروماك',
#  'ريتارد',
#  'مجم',
#  'كبسولة',
#  'ايراستابكس',
#  'مجم',
#  'قرص',
#  'تريب',
#  'جولد',
#  'كبسول',
#  'جويبوكس',
#  'مجم',
#  'قرص',
#  'ترنتال',
#  'مجم',
#  'قرص',
#  'سيردالود',
#  'مجم',
#  'قرص',
#  'فوربيودس',
#  'مكجم',
#  'كبسول',
#  'استنشاق',
#  'بيتاسيرك',
#  'مجم',
#  'قرص',
#  'رويال',
#  'شاى',
#  'ريجيم',
#  'فتلة',
#  'اتوريزا',
#  'مجم',
#  'قرص',
#  'موزابرايد',
#  'مجم',
#  'قرص',
#  'فياجرا',
#  'مجم',
#  'اقراص',
#  'ايراستابكس',
#  'مجم',
#  'قرص',
#  'تورسيريتك',
#  'مجم',
#  'قرص',
#  'استوهالت',
#  'مجم',
#  'كبسول',
#  'موبيتيل',
#  'مجم',
#  'قرص',
#  'تورسيريتك',
#  'قرص',
#  'بلوكاتنس',
#  'قرص',
#  'افيكسور',
#  'اكس',
#  'مجم',
#  'كبسول',
#  'سوفيناسين',
#  'مجم',
#  'قرص',
#  'اكوا',
#  'بلس',
#  'شراب',
#  'بيوفيت',
#  'ديبو',
#  'امبول',
#  'عضل',
#  'دياسيرين',
#  'مجم',
#  'كبسول',
#  'نيورونتين',
#  'مجم',
#  'كبسول',
#  'الكابرايد',
#  'مجم',
#  'قرص',
#  'نيفيلوب',
#  'بلس',
#  'مجم',
#  'قرص',
#  'ميوفين',
#  'كبسول',
#  'انتيكوكس',
#  'مجم',
#  'قرص',
#  'ليبراكس',
#  'قرص',
#  'روسيتور',
#  'مجم',
#  'قرص',
#  'ايراستابكس',
#  'بلس',
#  'مجم',
#  'قرص',
#  'ايسوبتن',
#  'ريتارد',
#  'مجم',
#  'قرص',
#  'افيفافاسك',
#  'مجم',
#  'قرص',
#  'سيريتايد',
#  'ديسكس',
#  'مكجم',
#  'جرعة',
#  'يوريبان',
#  'مجم',
#  'قرص',
#  'جستيكول',
#  'مجم',
#  'قرص',
#  'سيريتايد',
#  'ديسكس',
#  'مكجم',
#  'جرعة',
#  'جليبتس',
#  'بلس',
#  'مجم',
#  'قرص',
#  'كالدين',
#  'قرص',
#  'ريفارست',
#  'بلس',
#  'غسول',
#  'سينوبريل',
#  'مجم',
#  'قرص',
#  'فاكتو',
#  'مرهم',
#  'تادالونج',
#  'مجم',
#  'قرص',
#  'فلاكسوبرايد',
#  'مجم',
#  'قرص',
#  'سريع',
#  'الذوبان',
#  'بالفم',
#  'نورفاسك',
#  'مجم',
#  'قرص',
#  'اماريل',
#  'مجم',
#  'قرص',
#  'اجركس',
#  'مجم',
#  'قرص',
#  'دولفين',
#  'مجم',
#  'أقماع',
#  'بيبون',
#  'بلس',
#  'كبسول',
#  'روسيتور',
#  'مجم',
#  'قرص',
#  'اكساميد',
#  'مجم',
#  'قرص',
#  'اميبرايد',
#  'مجم',
#  'قرص',
#  'ايمباكوزا',
#  'مجم',
#  'قرص',
#  'البافيت',
#  'بالحديد',
#  'شراب',
#  'برونتوجيست',
#  'امبول',
#  'كلاريتين',
#  'شراب',
#  'تريتاس',
#  'مجم',
#  'قرص',
#  'اكتينون',
#  'مجم',
#  'قرص',
#  'موبيتيل',
#  'مجم',
#  'امبول',
#  'اكس',
#  'تينشن',
#  'بلس',
#  'مجم',
#  'قرص',
#  'تريتاس',
#  'كومب',
#  'قرص',
#  'بروستريد',
#  'مجم',
#  'كبسولة',
#  'كاندلكان',
#  'مجم',
#  'قرص',
#  'جليكودال',
#  'قرص',
#  'مضغ',
#  'اوستيوكير',
#  'شراب',
#  'زنك',
#  'اوليف',
#  'كريم',
#  'جرام',
#  'هيدروفيرين',
#  'نقط',
#  'بالفم',
#  'بريستافلام',
#  'مجم',
#  'قرص',
#  'رومانتيجرا',
#  'مجم',
#  'قرص',
#  'انتوبرال',
#  'مجم',
#  'قرص',
#  'كوليروز',
#  'مجم',
#  'قرص',
#  'فيسرالجين',
#  'مجم',
#  'قرص',
#  'اميجران',
#  'ادكو',
#  'قرص',
#  'اتور',
#  'مجم',
#  'قرص',
#  'اماريل',
#  'مجم',
#  'قرص',
#  'ميتاكارديا',
#  'مجم',
#  'قرص',
#  'هيلسيك',
#  'مجم',
#  'كبسولة',
#  'اريكتاليس',
#  'مجم',
#  'قرص',
#  'ديورجوي',
#  'مجم',
#  'قرص',
#  'افوصويا',
#  'كبسولة',
#  'سبانيلا',
#  'مجم',
#  'قرص',
#  'كاندلكان',
#  'بلس',
#  'مجم',
#  'قرص',
#  'اسبريكارلو',
#  'مجم',
#  'قرص',
#  'للمضغ',
#  ...]

# %%
from fuzzywuzzy import process

def correct_spelling(input_string):
    words = input_string.split()
    corrected_words = []
    for word in words:
        match, score = process.extractOne(word, all_words)
        if score >= 80:
            corrected_words.append(match)
        else:
            corrected_words.append(word)

    corrected_string = ' '.join(corrected_words)
    return corrected_string

# %%
correct_spelling("اوندالينزا 4 مجم كبسول")
# Out:
# 'اوندالينز 4 مجم كبسول'

# %%
dataset_df['seller_item_name_clean_spell'] = dataset_df['seller_item_name_clean'].apply(correct_spelling)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\fuzzywuzzy\process.py:108, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     106 try:
#     107     # See if choices is a dictionary-like object.
# --> 108     for key, choice in choices.items():
#     109         processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 dataset_df['seller_item_name_clean_spell'] = dataset_df['seller_item_name_clean'].apply(correct_spelling)
#
# File c:\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Python312\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Python312\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Python312\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[122], line 7, in correct_spelling(input_string)
#       5 corrected_words = []
#       6 for word in words:
# ----> 7     match, score = process.extractOne(word, all_words)
#       8     if score >= 80:
#       9         corrected_words.append(match)
#
# File c:\Python312\Lib\site-packages\fuzzywuzzy\process.py:220, in extractOne(query, choices, processor, scorer, score_cutoff)
#     218 best_list = extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     219 try:
# --> 220     return max(best_list, key=lambda i: i[1])
#     221 except ValueError:
#     222     return None
#
# File c:\Python312\Lib\site-packages\fuzzywuzzy\process.py:117, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     115 for choice in choices:
#     116     processed = pre_processor(processor(choice))
# --> 117     score = scorer(processed_query, processed)
#     118     if score >= score_cutoff:
#     119         yield (choice, score)
#
# File c:\Python312\Lib\site-packages\fuzzywuzzy\fuzz.py:291, in WRatio(s1, s2, force_ascii, full_process)
#     288     partial = partial_ratio(p1, p2) * partial_scale
#     289     ptsor = partial_token_sort_ratio(p1, p2, full_process=False) \
#     290         * unbase_scale * partial_scale
# --> 291     ptser = partial_token_set_ratio(p1, p2, full_process=False) \
#     292         * unbase_scale * partial_scale
#     294     return utils.intr(max(base, partial, ptsor, ptser))
#     295 else:
#
# File c:\Python312\Lib\site-packages\fuzzywuzzy\fuzz.py:173, in partial_token_set_ratio(s1, s2, force_ascii, full_process)
#     172 def partial_token_set_ratio(s1, s2, force_ascii=True, full_process=True):
# --> 173     return _token_set(s1, s2, partial=True, force_ascii=force_ascii, full_process=full_process)
#
# File c:\Python312\Lib\site-packages\fuzzywuzzy\utils.py:38, in check_for_none.<locals>.decorator(*args, **kwargs)
#      36 if args[0] is None or args[1] is None:
#      37     return 0
# ---> 38 return func(*args, **kwargs)
#
# File c:\Python312\Lib\site-packages\fuzzywuzzy\fuzz.py:162, in _token_set(s1, s2, partial, force_ascii, full_process)
#     157 else:
#     158     ratio_func = ratio
#     160 pairwise = [
#     161     ratio_func(sorted_sect, combined_1to2),
# --> 162     ratio_func(sorted_sect, combined_2to1),
#     163     ratio_func(combined_1to2, combined_2to1)
#     164 ]
#     165 return max(pairwise)
#
# File c:\Python312\Lib\site-packages\fuzzywuzzy\utils.py:34, in check_for_none.<locals>.decorator(*args, **kwargs)
#      33 def check_for_none(func):
# ---> 34     @functools.wraps(func)
#      35     def decorator(*args, **kwargs):
#      36         if args[0] is None or args[1] is None:
#      37             return 0
#
# KeyboardInterrupt:
